# %% [markdown]
# # 07.5 — Exploration: Text and Audio re-sampling + V-A probe
#
# **Purpose.** A standalone, additive notebook. It does **not** modify
# `02_Embeddings/` or `03_Final_Results/` and does not depend on rerunning
# notebooks 02–06. Every run writes to a fresh timestamped subfolder of
# `Explorations 2.0/`.
#
# **Inputs (read-only):**
#   - `01_Processed_Data/metadata.csv`
#   - `01_Processed_Data/audio/*.wav`
#   - `01_Processed_Data/lyrics/*.txt`
#   - `02_Embeddings/*.npy`     (the six original embedding sets from nb02–04)
#
# **Outputs per run** (written to `Explorations 2.0/run_YYYY-MM-DD_HH-MM/`):
#   - `embeddings/`             — four NEW audio embedding sets (random + energy-peak × IB + MERT)
#                               + four NEW text  embedding sets (chorus + multi-segment × IB-text + CLAP)
#   - `embeddings/labels.csv`   — five alternative labelings used by methods 1–5
#   - `embeddings/lyric_chorus_log.csv` — detected chorus + character counts per track
#   - `results/`                — CSVs from each analysis (incl. V-A R² table)
#   - `figures/`                — ~14 PNGs (incl. V-A circumplex pre/post)
#   - `summary.md`              — short markdown writeup of the top findings
#
# **The five analyses** (run on the original 6 spaces *and* the 4 newly resampled
# audio spaces *and* the 4 newly resampled text spaces — 14 encoder-spaces total):
# 1. K-means in each space, then per-cluster purity by every label scheme.
# 2. Per-track top-K nearest neighbors per encoder + 5 diagnostic-track listings.
# 3. Silhouette by alternative labelings — bar chart + heatmap.
# 4. Cross-encoder neighbor-Jaccard maps — finds tracks each encoder uniquely sees.
# 5. Block-sorted 150×150 similarity heatmaps per label scheme.
#
# **Plus a V-A probe section** (NEW in 07.5):
#   - V-A1  Linear regression from each encoder's embedding to anchor V-A coordinates,
#           scored with leave-one-out cross-validation R².  This is *anchor-based*
#           — Y has only 6 distinct values — so it is not a real V-A study, but it
#           quantifies how cleanly each encoder separates the 6 emotion categories
#           along V-A axes.
#   - V-A2  Side-by-side pre/post visualization of V-A predicted centroids on
#           Russell's circumplex for two encoder pairs:
#               audio_ib_orig   vs   audio_ib_energy
#               text_clap       vs   text_clap_chorus
#           The closer a predicted centroid is to its anchor, the better that
#           encoder represents the emotion under V-A.
#
# **Design notes.**
#   - Every cell is **defensively re-importable** so a Colab kernel restart in the
#     middle of the notebook does not break later cells.
#   - Random seed pinned (default `SEED=42`) for reproducibility within a run; vary
#     `SEED` between runs if you want a Monte-Carlo estimate of the random-K-mean
#     audio embedding.
#   - All cosine math L2-normalizes its inputs first; ImageBind/MERT raw outputs
#     are **not** unit-norm.

# %%
# === CELL 1 — Drive mount + create timestamped Explorations/run folder ===
from google.colab import drive
import os
from datetime import datetime
from pathlib import Path

drive.mount('/content/drive', force_remount=False)

# --- canonical project paths (match nb01–06) -----------------------------
PROJECT_ROOT  = "/content/drive/MyDrive/DL_Project_2026"
PROCESSED_DIR = os.path.join(PROJECT_ROOT, "01_Processed_Data")
EMBED_DIR     = os.path.join(PROJECT_ROOT, "02_Embeddings")
RESULTS_DIR   = os.path.join(PROJECT_ROOT, "03_Final_Results")
EXPLORE_ROOT  = os.path.join(PROJECT_ROOT, "Explorations 2.0")

# --- create per-run subfolder ---------------------------------------------
RUN_STAMP   = datetime.now().strftime("%Y-%m-%d_%H-%M")
RUN_DIR     = os.path.join(EXPLORE_ROOT, f"run_{RUN_STAMP}")
EMB_OUT     = os.path.join(RUN_DIR, "embeddings")
RES_OUT     = os.path.join(RUN_DIR, "results")
FIG_OUT     = os.path.join(RUN_DIR, "figures")
for d in (EMB_OUT, RES_OUT, FIG_OUT):
    os.makedirs(d, exist_ok=True)

# --- contract assertions: project skeleton must exist ---------------------
assert os.path.isdir(PROCESSED_DIR), f"Missing {PROCESSED_DIR} — run nb01 first."
assert os.path.isdir(EMBED_DIR),     f"Missing {EMBED_DIR} — run nb02–04 first."

NOTEBOOK_ID = "07"
SEED = 18

#Seeds ran: 42, 65, 18

print(f"📁  Run folder:        {RUN_DIR}")
print(f"📁  Read embeddings:   {EMBED_DIR}")
print(f"📁  Read processed:    {PROCESSED_DIR}")
# Out:
# Mounted at /content/drive
# 📁  Run folder:        /content/drive/MyDrive/DL_Project_2026/Explorations 2.0/run_2026-05-06_06-08
# 📁  Read embeddings:   /content/drive/MyDrive/DL_Project_2026/02_Embeddings
# 📁  Read processed:    /content/drive/MyDrive/DL_Project_2026/01_Processed_Data

# %%
# === CELL 2 — Imports + small utilities ===
# Defensive re-import block so this cell can be re-run after a kernel restart.
import os, json, math, time, warnings, random
from pathlib import Path
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.preprocessing import normalize
from sklearn.neighbors import NearestNeighbors
warnings.filterwarnings("ignore")

# Reproducibility
np.random.seed(SEED); random.seed(SEED)

# Tiny helpers ------------------------------------------------------------
def l2(X):
    """Row-wise L2-normalize (safe)."""
    return normalize(X.astype(np.float32), norm="l2", axis=1)

def cos_sim(A, B=None):
    """Cosine similarity. If B is None, computes A vs A."""
    A = l2(A); B = l2(B) if B is not None else A
    return A @ B.T

def topk_neighbors(X, k=5, exclude_self=True):
    """For each row of X, return indices of its top-k cosine neighbors."""
    sim = cos_sim(X)
    if exclude_self:
        np.fill_diagonal(sim, -np.inf)
    return np.argsort(-sim, axis=1)[:, :k]

def jaccard_top(setA, setB):
    """Jaccard between two top-k neighbor sets (tuples of int)."""
    a, b = set(setA), set(setB)
    return len(a & b) / max(1, len(a | b))

def cluster_purity(labels_pred, labels_true):
    """Standard purity. Both 1-D int arrays of equal length."""
    from collections import Counter
    total = len(labels_pred); correct = 0
    for c in np.unique(labels_pred):
        members = labels_true[labels_pred == c]
        if len(members) == 0: continue
        most_common = Counter(members).most_common(1)[0][1]
        correct += most_common
    return correct / total

print("✅ utilities ready")
# Out:
# ✅ utilities ready

# %%
# === CELL 3 — Metadata + alternative label schemes ===
import os, re, pandas as pd, numpy as np
metadata = pd.read_csv(os.path.join(PROCESSED_DIR, "metadata.csv"))
N = len(metadata)
assert N == 150, f"Expected 150 tracks, got {N}"

# --- 1. Emotion (already in metadata) -----------------------------------
metadata["label_emotion"] = metadata["emotion_category"]

# --- 2. Subcategory (already in metadata) -------------------------------
metadata["label_subcategory"] = metadata["emotion_subcategory"]

# --- 3. Contributor (already in metadata) -------------------------------
metadata["label_contributor"] = metadata["contributor"]

# --- 4. Genre top-level (parse text BEFORE the first '/' or '[') --------
def parse_genre_top(g):
    if not isinstance(g, str) or not g.strip():
        return "Unknown"
    s = g.strip()
    # split on '[' first to drop sub-genre brackets, then on '/' for top family
    s = s.split("[")[0].strip()
    s = s.split("/")[0].strip()
    return s if s else "Unknown"
metadata["label_genre_top"] = metadata["genre"].apply(parse_genre_top)

# --- 5. Vocal-vs-instrumental — derived from lyrics file content --------
def has_vocal(lyric_rel_path):
    full = os.path.join(PROJECT_ROOT, lyric_rel_path) if isinstance(lyric_rel_path, str) else None
    if not full or not os.path.exists(full):
        return "instrumental"
    try:
        with open(full, "r", encoding="utf-8", errors="ignore") as f:
            txt = f.read().strip()
        return "vocal" if len(txt) > 50 else "instrumental"
    except Exception:
        return "vocal"
metadata["label_vocal"] = metadata["lyrics_path"].apply(has_vocal)

# --- 6. Audio-duration bucket (computed from .wav files) -----------------
import wave, contextlib
def wav_seconds(rel_path):
    full = os.path.join(PROJECT_ROOT, rel_path) if isinstance(rel_path, str) else None
    if not full or not os.path.exists(full):
        return np.nan
    try:
        with contextlib.closing(wave.open(full, "rb")) as w:
            return w.getnframes() / float(w.getframerate())
    except Exception:
        return np.nan
metadata["audio_seconds"] = metadata["standardized_audio_path"].apply(wav_seconds)
def dur_bucket(s):
    if pd.isna(s): return "unknown"
    if s < 150: return "short(<2.5min)"
    if s < 240: return "medium(2.5-4min)"
    return "long(>4min)"
metadata["label_duration_bucket"] = metadata["audio_seconds"].apply(dur_bucket)

LABEL_COLS = [
    "label_emotion", "label_subcategory", "label_contributor",
    "label_genre_top", "label_vocal", "label_duration_bucket",
]

# Save the labels file for downstream traceability
labels_path = os.path.join(EMB_OUT, "labels.csv")
metadata[["track_id","song_title","artist_name"] + LABEL_COLS].to_csv(labels_path, index=False)

# Print summary
print("Label scheme value counts:")
for col in LABEL_COLS:
    n_unique = metadata[col].nunique()
    print(f"  {col:30s}  {n_unique:3d} levels")
print(f"\n💾 saved {labels_path}")
# Out:
# Label scheme value counts:
#   label_emotion                     6 levels
#   label_subcategory                24 levels
#   label_contributor                 5 levels
#   label_genre_top                  11 levels
#   label_vocal                       1 levels
#   label_duration_bucket             1 levels
#
# 💾 saved /content/drive/MyDrive/DL_Project_2026/Explorations 2.0/run_2026-05-06_06-08/embeddings/labels.csv

# %%
# === CELL 4 — Load the SIX original embedding sets from nb02–04 ===
import os, numpy as np

ORIGINAL_FILES = {
    "audio_ib_orig":   "audio_ib_embeddings.npy",
    "audio_mert_orig": "audio_embeddings_MERT.npy",
    "image_ib":        "image_ib_embeddings.npy",
    "image_clip":      "image_clip_embeddings.npy",
    "text_ib":         "text_ib_embeddings.npy",
    "text_clap":       "text_clap_embeddings.npy",
}

ORIG_EMB = {}
for name, fname in ORIGINAL_FILES.items():
    p = os.path.join(EMBED_DIR, fname)
    assert os.path.exists(p), f"Missing {p} — run nb02–04 first."
    arr = np.load(p)
    assert arr.shape[0] == 150, f"{fname} has {arr.shape[0]} rows, expected 150"
    ORIG_EMB[name] = arr.astype(np.float32)
    print(f"  {name:18s}  {arr.shape}  dtype={arr.dtype}")
# Out:
#   audio_ib_orig       (150, 1024)  dtype=float32
#   audio_mert_orig     (150, 768)  dtype=float32
#   image_ib            (150, 1024)  dtype=float32
#   image_clip          (150, 512)  dtype=float32
#   text_ib             (150, 1024)  dtype=float32
#   text_clap           (150, 512)  dtype=float32

# %%
# === CELL 5 — Install + load ImageBind & MERT (skip if you don't re-extract) ===
# This cell is heavy (~3-4 min on a fresh Colab). Skip if RUN_REEXTRACT = False.

RUN_REEXTRACT = True   # toggle to False if you only want analysis on original embeddings

if RUN_REEXTRACT:
    import sys, subprocess, importlib

    def pip_q(args):
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q"] + args)

    try:
        import imagebind, transformers, torchaudio  # noqa
    except Exception:
        print("📦 installing ImageBind + transformers + torchaudio + librosa ...")
        pip_q(["git+https://github.com/facebookresearch/ImageBind.git"])
        pip_q(["transformers", "torchaudio", "librosa"])

    import torch, torchaudio
    import torchaudio.transforms as T
    from imagebind import data as ib_data
    from imagebind.models import imagebind_model
    from imagebind.models.imagebind_model import ModalityType
    from transformers import AutoModel, Wav2Vec2FeatureExtractor

    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"🖥️  device: {DEVICE}")

    print("🧠 loading ImageBind huge ...")
    IB_MODEL = imagebind_model.imagebind_huge(pretrained=True).to(DEVICE).eval()

    print("🎸 loading MERT-v1-95M ...")
    MERT_MODEL = AutoModel.from_pretrained(
        "m-a-p/MERT-v1-95M", trust_remote_code=True
    ).to(DEVICE).eval()
    MERT_PROC = Wav2Vec2FeatureExtractor.from_pretrained(
        "m-a-p/MERT-v1-95M", trust_remote_code=True
    )
    MERT_SR = MERT_PROC.sampling_rate    # 24_000
    print("✅ models loaded")
else:
    print("ℹ️  RUN_REEXTRACT is False — Cells 6–7 will reuse only the original embeddings.")
# Out:
# 📦 installing ImageBind + transformers + torchaudio + librosa ...
# 🖥️  device: cuda
# 🧠 loading ImageBind huge ...
# Downloading imagebind weights to .checkpoints/imagebind_huge.pth ...
# 100%|██████████| 4.47G/4.47G [02:52<00:00, 27.8MB/s]
# 🎸 loading MERT-v1-95M ...
# config.json: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# configuration_MERT.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/m-a-p/MERT-v1-95M:
# - configuration_MERT.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_MERT.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/m-a-p/MERT-v1-95M:
# - modeling_MERT.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING: feature_extractor_cqt requires the libray 'nnAudio'
# pytorch_model.bin:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/211 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]
# ✅ models loaded

# %%
# === CELL 6 — Re-extract AUDIO with two new sampling methods ===
# RANDOM-K-mean : K random 2-second windows, mean-pool the K embeddings
# ENERGY-PEAK   : K windows around the K highest-RMS-energy moments
#
# We re-extract with BOTH ImageBind audio and MERT, giving 4 new embedding sets.
# Image and text are not re-extracted — sampling matters only for audio.

if RUN_REEXTRACT:
    import os, numpy as np, torch, torchaudio
    import librosa
    import tempfile, soundfile as sf
    from pathlib import Path

    K_CLIPS  = 5      # number of clips per track for both methods
    CLIP_SEC = 2.0    # seconds per clip — matches ImageBind's expected audio length
    MERT_CLIP_SEC = 10.0  # MERT can take longer, gives richer per-clip rep
    HOP_SEC  = 0.5    # for energy peak detection

    audio_paths = [
        os.path.join(PROJECT_ROOT, p)
        for p in metadata["standardized_audio_path"].tolist()
    ]

    # ---- helper: pick energy-peak start times ---------------------------
    def peak_starts(wav_np, sr, n_peaks, clip_sec):
        """Return n_peaks distinct start-time offsets (seconds) at local RMS maxima.
        wav_np 1-D mono float32. Falls back to evenly spaced if too few peaks."""
        frame = int(0.05 * sr)               # 50 ms frame
        hop   = int(HOP_SEC * sr)
        rms = librosa.feature.rms(y=wav_np, frame_length=frame, hop_length=hop)[0]
        # keep only candidates with at least clip_sec of audio after them
        max_start_frame = max(1, len(rms) - int(clip_sec / HOP_SEC))
        rms = rms[:max_start_frame]
        if len(rms) <= n_peaks:
            return np.linspace(0, max(0, len(wav_np)/sr - clip_sec), n_peaks)
        order = np.argsort(-rms)
        chosen = []
        for idx in order:
            t = idx * HOP_SEC
            if all(abs(t - c) > clip_sec for c in chosen):
                chosen.append(t)
            if len(chosen) == n_peaks: break
        if len(chosen) < n_peaks:
            extra = np.linspace(0, max(0, len(wav_np)/sr - clip_sec), n_peaks - len(chosen))
            chosen.extend(extra.tolist())
        return np.array(chosen[:n_peaks])

    def random_starts(wav_np, sr, n_clips, clip_sec, rng):
        max_start = max(0.0, len(wav_np)/sr - clip_sec)
        return rng.uniform(0, max_start, size=n_clips) if max_start > 0 else np.zeros(n_clips)

    def write_temp_wav(wav_np, sr, out_path):
        sf.write(out_path, wav_np, sr, subtype="PCM_16")

    # ---- ImageBind sampler --------------------------------------------------
    def ib_embed_clips(wav_path, starts, clip_sec=CLIP_SEC):
        """Slice wav into clips of length clip_sec at the given start offsets,
        write to temp files, run ImageBind on the batch, return mean embedding."""
        wav, sr = librosa.load(wav_path, sr=16000, mono=True)  # IB expects 16k
        embs = []
        with tempfile.TemporaryDirectory() as tmpdir:
            tmp_paths = []
            for i, t in enumerate(starts):
                a = int(t * sr); b = a + int(clip_sec * sr)
                clip = wav[a:b]
                if len(clip) < int(clip_sec * sr):     # pad if short
                    clip = np.pad(clip, (0, int(clip_sec * sr) - len(clip)))
                tp = os.path.join(tmpdir, f"clip_{i}.wav")
                write_temp_wav(clip, sr, tp)
                tmp_paths.append(tp)
            batch = ib_data.load_and_transform_audio_data(tmp_paths, DEVICE)
            with torch.no_grad():
                out = IB_MODEL({ModalityType.AUDIO: batch})
            embs = out[ModalityType.AUDIO].detach().cpu().numpy().astype(np.float32)
        return embs.mean(axis=0)   # (1024,)

    # ---- MERT sampler -------------------------------------------------------
    def mert_embed_clips(wav_path, starts, clip_sec=MERT_CLIP_SEC):
        wav_t, sr = torchaudio.load(wav_path)
        if wav_t.shape[0] > 1: wav_t = wav_t.mean(0, keepdim=True)
        if sr != MERT_SR:
            wav_t = torchaudio.transforms.Resample(sr, MERT_SR)(wav_t)
            sr = MERT_SR
        wav_np = wav_t.squeeze().numpy()
        per_clip_emb = []
        for t in starts:
            a = int(t * sr); b = a + int(clip_sec * sr)
            clip = wav_np[a:b]
            if len(clip) < int(0.5 * sr):       # too short to be useful
                continue
            inp = MERT_PROC(clip, sampling_rate=MERT_SR, return_tensors="pt")
            inp = {k: v.to(DEVICE) for k, v in inp.items()}
            with torch.no_grad():
                out = MERT_MODEL(**inp, output_hidden_states=True)
            layers = torch.stack(out.hidden_states).squeeze(1)
            time_mean  = layers.mean(dim=1)
            layer_mean = time_mean.mean(dim=0)
            per_clip_emb.append(layer_mean.cpu().numpy().astype(np.float32))
        if not per_clip_emb:
            # fallback: full-track embedding
            inp = MERT_PROC(wav_np, sampling_rate=MERT_SR, return_tensors="pt")
            inp = {k: v.to(DEVICE) for k, v in inp.items()}
            with torch.no_grad():
                out = MERT_MODEL(**inp, output_hidden_states=True)
            layers = torch.stack(out.hidden_states).squeeze(1)
            return layers.mean(dim=1).mean(dim=0).cpu().numpy().astype(np.float32)
        return np.stack(per_clip_emb).mean(axis=0)

    rng = np.random.default_rng(SEED)

    audio_ib_random   = np.zeros((N, 1024), dtype=np.float32)
    audio_ib_energy   = np.zeros((N, 1024), dtype=np.float32)
    audio_mert_random = np.zeros((N,  768), dtype=np.float32)
    audio_mert_energy = np.zeros((N,  768), dtype=np.float32)

    print(f"🎧 re-extracting (K={K_CLIPS} clips · {CLIP_SEC}s IB · {MERT_CLIP_SEC}s MERT) ...")
    for i, wav_path in enumerate(audio_paths):
        # Load once for energy detection
        wav, sr = librosa.load(wav_path, sr=16000, mono=True)
        rnd = random_starts(wav, sr, K_CLIPS, CLIP_SEC, rng)
        peak = peak_starts(wav, sr, K_CLIPS, CLIP_SEC)

        # Same start-times for both encoders so methods are comparable
        # (but MERT uses LONGER clips around the same centers)
        rnd_mert  = np.clip(rnd  - (MERT_CLIP_SEC - CLIP_SEC) / 2, 0, None)
        peak_mert = np.clip(peak - (MERT_CLIP_SEC - CLIP_SEC) / 2, 0, None)

        audio_ib_random[i]   = ib_embed_clips(wav_path, rnd)
        audio_ib_energy[i]   = ib_embed_clips(wav_path, peak)
        audio_mert_random[i] = mert_embed_clips(wav_path, rnd_mert)
        audio_mert_energy[i] = mert_embed_clips(wav_path, peak_mert)

        if (i+1) % 10 == 0 or i == 0:
            print(f"   [{i+1:3d}/{N}]  {os.path.basename(wav_path)}")

    # Save
    np.save(os.path.join(EMB_OUT, "audio_ib_random.npy"),   audio_ib_random)
    np.save(os.path.join(EMB_OUT, "audio_ib_energy.npy"),   audio_ib_energy)
    np.save(os.path.join(EMB_OUT, "audio_mert_random.npy"), audio_mert_random)
    np.save(os.path.join(EMB_OUT, "audio_mert_energy.npy"), audio_mert_energy)

    # Validation
    for nm, arr in [("audio_ib_random", audio_ib_random),
                     ("audio_ib_energy", audio_ib_energy),
                     ("audio_mert_random", audio_mert_random),
                     ("audio_mert_energy", audio_mert_energy)]:
        assert arr.shape[0] == 150 and np.isfinite(arr).all(), nm
        print(f"  💾 {nm:20s} {arr.shape}")

    print("✅ re-extraction complete")
else:
    print("ℹ️  skipped re-extraction (RUN_REEXTRACT=False).  Cells below will use only original embeddings.")
# Out:
# 🎧 re-extracting (K=5 clips · 2.0s IB · 10.0s MERT) ...
#    [  1/150]  track_001.wav
#    [ 10/150]  track_010.wav
#    [ 20/150]  track_020.wav
#    [ 30/150]  track_030.wav
#    [ 40/150]  track_040.wav
#    [ 50/150]  track_050.wav
#    [ 60/150]  track_060.wav
#    [ 70/150]  track_070.wav
#    [ 80/150]  track_080.wav
#    [ 90/150]  track_090.wav
#    [100/150]  track_100.wav
#    [110/150]  track_110.wav
#    [120/150]  track_120.wav
#    [130/150]  track_130.wav
#    [140/150]  track_140.wav
#    [150/150]  track_150.wav
#   💾 audio_ib_random      (150, 1024)
#   💾 audio_ib_energy      (150, 1024)
#   💾 audio_mert_random    (150, 768)
#   💾 audio_mert_energy    (150, 768)
# ✅ re-extraction complete

# %%
# === CELL 6b — Re-extract LYRIC embeddings with two new sampling methods ===
# CHORUS-ONLY     : detect the longest repeated phrase in each lyric, embed only that
# MULTI-SEGMENT   : split each lyric into K=4 chunks, embed each, mean-pool them
#
# Why: ImageBind text and CLAP both inherit CLIP's BPE tokenizer with a 77-token
# context window (~300 chars).  Combined with nb01's 1000-char file cap, the
# original embeddings only ever saw the first verse of each song.  Choruses,
# bridges, and outros — the most repeated and most emotionally loaded sections
# — were invisible.  This cell is the lyric analog of the audio energy-peak
# sampler in Cell 6.

if RUN_REEXTRACT:
    import os, re, numpy as np, torch
    from collections import Counter

    # ----- 1. helpers -----------------------------------------------------
    def find_chorus(lyric_text, min_words=4, max_words=12):
        """Longest repeated phrase that appears >=2 times.  None if no clear
        repetition.  We sweep phrase length L from longest to shortest so the
        most informative (longest) repeated phrase wins."""
        text = re.sub(r"\s+", " ", lyric_text).strip().lower()
        words = re.findall(r"\b[\w']+\b", text)
        if len(words) < min_words * 2:
            return None
        for L in range(min(max_words, len(words) // 2), min_words - 1, -1):
            ngrams = Counter(tuple(words[i:i+L]) for i in range(len(words) - L + 1))
            top, count = ngrams.most_common(1)[0]
            if count >= 2:
                return " ".join(top)
        return None

    def chunk_lyric(lyric_text, K=4):
        """Split a lyric into K roughly-equal character-chunks.  Returns a
        list of K strings; if the lyric is too short to chunk meaningfully,
        returns the whole text in a single-element list."""
        L = len(lyric_text)
        if L < 100:
            return [lyric_text or ""]
        cs = L // K
        return [lyric_text[i*cs:(i+1)*cs] for i in range(K)]

    # ----- 2. CLAP load (IB-text reuses IB_MODEL already loaded in Cell 5) -
    try:
        import laion_clap
    except Exception:
        import sys, subprocess
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "laion_clap"])
        import laion_clap
    print("🎼 loading CLAP HTSAT-tiny ...")
    CLAP_MODEL = laion_clap.CLAP_Module(enable_fusion=False, device=DEVICE)
    CLAP_MODEL.load_ckpt()           # default htsat-tiny
    print("✅ CLAP loaded")

    from imagebind import data as ib_data
    from imagebind.models.imagebind_model import ModalityType

    def ib_text_embed(text_list, batch=32):
        """Run a list of strings through ImageBind text in batches; (n, 1024)."""
        out_chunks = []
        for i in range(0, len(text_list), batch):
            sub = text_list[i:i+batch]
            tokens = ib_data.load_and_transform_text(sub, DEVICE)
            with torch.no_grad():
                out = IB_MODEL({ModalityType.TEXT: tokens})
            out_chunks.append(out[ModalityType.TEXT].detach().cpu().numpy().astype(np.float32))
        return np.concatenate(out_chunks, axis=0)

    def clap_text_embed(text_list):
        """CLAP text embedding (n, 512)."""
        with torch.no_grad():
            return CLAP_MODEL.get_text_embedding(text_list, use_tensor=False).astype(np.float32)

    # ----- 3. read full lyrics from disk ----------------------------------
    lyric_paths = [os.path.join(PROJECT_ROOT, p) for p in metadata["lyrics_path"].tolist()]
    full_lyrics = []
    for p in lyric_paths:
        if os.path.exists(p):
            with open(p, "r", encoding="utf-8", errors="ignore") as f:
                full_lyrics.append(f.read().strip())
        else:
            full_lyrics.append("")
    n_chars = np.array([len(t) for t in full_lyrics])
    print(f"📜 lyric character stats: median={np.median(n_chars):.0f}  max={n_chars.max()}  "
          f"hits-1000-cap={int((n_chars >= 1000).sum())}/{N}")

    # ----- 4. chorus per track --------------------------------------------
    chorus_texts = []
    n_chorus_found = 0
    for t in full_lyrics:
        c = find_chorus(t)
        if c is None:
            chorus_texts.append(t[:300] if t else "")     # fallback to first 300 chars
        else:
            chorus_texts.append(c)
            n_chorus_found += 1
    print(f"🎤 chorus detected for {n_chorus_found}/{N} tracks  "
          f"(remainder fall back to first 300 chars)")

    # ----- 5. ImageBind-text — chorus + multi-segment ---------------------
    print("🧠 IB-text · chorus ...")
    text_ib_chorus = ib_text_embed(chorus_texts)

    print("🧠 IB-text · multi-segment (K=4 chunks per track, mean-pooled) ...")
    text_ib_multi = np.zeros((N, 1024), dtype=np.float32)
    for i, lyric in enumerate(full_lyrics):
        chunks = chunk_lyric(lyric, K=4)
        chunk_emb = ib_text_embed(chunks)
        text_ib_multi[i] = chunk_emb.mean(axis=0)
        if (i+1) % 25 == 0 or i == 0:
            print(f"   IB-text-multi  [{i+1:3d}/{N}]")

    # ----- 6. CLAP-text — chorus + multi-segment --------------------------
    print("🎼 CLAP-text · chorus ...")
    text_clap_chorus = clap_text_embed(chorus_texts)

    print("🎼 CLAP-text · multi-segment ...")
    text_clap_multi = np.zeros((N, 512), dtype=np.float32)
    for i, lyric in enumerate(full_lyrics):
        chunks = chunk_lyric(lyric, K=4)
        chunk_emb = clap_text_embed(chunks)
        text_clap_multi[i] = chunk_emb.mean(axis=0)
        if (i+1) % 25 == 0 or i == 0:
            print(f"   CLAP-text-multi [{i+1:3d}/{N}]")

    # ----- 7. validate + save --------------------------------------------
    for nm, arr in [("text_ib_chorus", text_ib_chorus),
                    ("text_ib_multi",  text_ib_multi),
                    ("text_clap_chorus", text_clap_chorus),
                    ("text_clap_multi",  text_clap_multi)]:
        assert arr.shape[0] == 150 and np.isfinite(arr).all(), nm
        np.save(os.path.join(EMB_OUT, f"{nm}.npy"), arr)
        print(f"  💾 {nm:22s} {arr.shape}")

    # also save the chorus texts for inspection
    import pandas as pd
    pd.DataFrame({
        "track_id":     metadata["track_id"],
        "song_title":   metadata["song_title"],
        "n_chars":      [len(t) for t in full_lyrics],
        "chorus_used":  [c for c in chorus_texts],
        "chorus_found": [bool(find_chorus(t)) for t in full_lyrics],
    }).to_csv(os.path.join(EMB_OUT, "lyric_chorus_log.csv"), index=False)
    print("✅ lyric re-extraction complete (chorus + multi-segment)")
else:
    print("ℹ️  skipped lyric re-extraction (RUN_REEXTRACT=False)")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 🎼 loading CLAP HTSAT-tiny ...
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# RobertaModel LOAD REPORT from: roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# roberta.embeddings.position_ids | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# lm_head.bias                    | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# pooler.dense.bias               | MISSING    |
# pooler.dense.weight             | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Load our best checkpoint in the paper.
# Downloading laion_clap weight files...
# Download completed!
# Load Checkpoint...
# logit_scale_a 	 Loaded
# logit_scale_t 	 Loaded
# audio_branch.spectrogram_extractor.stft.conv_real.weight 	 Loaded
# audio_branch.spectrogram_extractor.stft.conv_imag.weight 	 Loaded
# audio_branch.logmel_extractor.melW 	 Loaded
# audio_branch.bn0.weight 	 Loaded
# audio_branch.bn0.bias 	 Loaded
# audio_branch.patch_embed.proj.weight 	 Loaded
# audio_branch.patch_embed.proj.bias 	 Loaded
# audio_branch.patch_embed.norm.weight 	 Loaded
# audio_branch.patch_embed.norm.bias 	 Loaded
# audio_branch.layers.0.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.0.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.0.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.0.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.0.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.0.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.0.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.0.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.0.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.0.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.0.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.0.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.0.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.0.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.0.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.0.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.0.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.0.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.0.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.0.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.layers.0.downsample.reduction.weight 	 Loaded
# audio_branch.layers.0.downsample.norm.weight 	 Loaded
# audio_branch.layers.0.downsample.norm.bias 	 Loaded
# audio_branch.layers.1.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.1.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.1.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.1.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.1.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.1.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.1.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.1.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.1.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.1.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.1.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.1.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.1.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.1.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.1.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.1.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.1.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.1.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.1.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.1.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.layers.1.downsample.reduction.weight 	 Loaded
# audio_branch.layers.1.downsample.norm.weight 	 Loaded
# audio_branch.layers.1.downsample.norm.bias 	 Loaded
# audio_branch.layers.2.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.2.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.2.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.2.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.2.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.2.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.2.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.2.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.2.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.2.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.2.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.3.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.3.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.3.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.3.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.3.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.3.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.3.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.3.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.3.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.3.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.4.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.4.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.4.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.4.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.4.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.4.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.4.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.4.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.4.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.4.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.blocks.5.norm1.weight 	 Loaded
# audio_branch.layers.2.blocks.5.norm1.bias 	 Loaded
# audio_branch.layers.2.blocks.5.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.2.blocks.5.attn.qkv.weight 	 Loaded
# audio_branch.layers.2.blocks.5.attn.qkv.bias 	 Loaded
# audio_branch.layers.2.blocks.5.attn.proj.weight 	 Loaded
# audio_branch.layers.2.blocks.5.attn.proj.bias 	 Loaded
# audio_branch.layers.2.blocks.5.norm2.weight 	 Loaded
# audio_branch.layers.2.blocks.5.norm2.bias 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc1.weight 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc1.bias 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc2.weight 	 Loaded
# audio_branch.layers.2.blocks.5.mlp.fc2.bias 	 Loaded
# audio_branch.layers.2.downsample.reduction.weight 	 Loaded
# audio_branch.layers.2.downsample.norm.weight 	 Loaded
# audio_branch.layers.2.downsample.norm.bias 	 Loaded
# audio_branch.layers.3.blocks.0.norm1.weight 	 Loaded
# audio_branch.layers.3.blocks.0.norm1.bias 	 Loaded
# audio_branch.layers.3.blocks.0.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.3.blocks.0.attn.qkv.weight 	 Loaded
# audio_branch.layers.3.blocks.0.attn.qkv.bias 	 Loaded
# audio_branch.layers.3.blocks.0.attn.proj.weight 	 Loaded
# audio_branch.layers.3.blocks.0.attn.proj.bias 	 Loaded
# audio_branch.layers.3.blocks.0.norm2.weight 	 Loaded
# audio_branch.layers.3.blocks.0.norm2.bias 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc1.weight 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc1.bias 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc2.weight 	 Loaded
# audio_branch.layers.3.blocks.0.mlp.fc2.bias 	 Loaded
# audio_branch.layers.3.blocks.1.norm1.weight 	 Loaded
# audio_branch.layers.3.blocks.1.norm1.bias 	 Loaded
# audio_branch.layers.3.blocks.1.attn.relative_position_bias_table 	 Loaded
# audio_branch.layers.3.blocks.1.attn.qkv.weight 	 Loaded
# audio_branch.layers.3.blocks.1.attn.qkv.bias 	 Loaded
# audio_branch.layers.3.blocks.1.attn.proj.weight 	 Loaded
# audio_branch.layers.3.blocks.1.attn.proj.bias 	 Loaded
# audio_branch.layers.3.blocks.1.norm2.weight 	 Loaded
# audio_branch.layers.3.blocks.1.norm2.bias 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc1.weight 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc1.bias 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc2.weight 	 Loaded
# audio_branch.layers.3.blocks.1.mlp.fc2.bias 	 Loaded
# audio_branch.norm.weight 	 Loaded
# audio_branch.norm.bias 	 Loaded
# audio_branch.tscam_conv.weight 	 Loaded
# audio_branch.tscam_conv.bias 	 Loaded
# audio_branch.head.weight 	 Loaded
# audio_branch.head.bias 	 Loaded
# text_branch.embeddings.word_embeddings.weight 	 Loaded
# text_branch.embeddings.token_type_embeddings.weight 	 Loaded
# text_branch.embeddings.LayerNorm.weight 	 Loaded
# text_branch.embeddings.LayerNorm.bias 	 Loaded
# text_branch.embeddings.position_embeddings.weight 	 Loaded
# text_branch.encoder.layer.0.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.0.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.0.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.0.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.0.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.0.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.0.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.0.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.0.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.0.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.0.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.0.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.0.output.dense.weight 	 Loaded
# text_branch.encoder.layer.0.output.dense.bias 	 Loaded
# text_branch.encoder.layer.0.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.0.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.1.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.1.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.1.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.1.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.1.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.1.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.1.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.1.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.1.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.1.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.1.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.1.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.1.output.dense.weight 	 Loaded
# text_branch.encoder.layer.1.output.dense.bias 	 Loaded
# text_branch.encoder.layer.1.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.1.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.2.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.2.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.2.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.2.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.2.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.2.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.2.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.2.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.2.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.2.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.2.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.2.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.2.output.dense.weight 	 Loaded
# text_branch.encoder.layer.2.output.dense.bias 	 Loaded
# text_branch.encoder.layer.2.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.2.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.3.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.3.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.3.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.3.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.3.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.3.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.3.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.3.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.3.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.3.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.3.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.3.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.3.output.dense.weight 	 Loaded
# text_branch.encoder.layer.3.output.dense.bias 	 Loaded
# text_branch.encoder.layer.3.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.3.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.4.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.4.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.4.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.4.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.4.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.4.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.4.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.4.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.4.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.4.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.4.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.4.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.4.output.dense.weight 	 Loaded
# text_branch.encoder.layer.4.output.dense.bias 	 Loaded
# text_branch.encoder.layer.4.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.4.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.5.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.5.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.5.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.5.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.5.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.5.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.5.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.5.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.5.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.5.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.5.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.5.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.5.output.dense.weight 	 Loaded
# text_branch.encoder.layer.5.output.dense.bias 	 Loaded
# text_branch.encoder.layer.5.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.5.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.6.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.6.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.6.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.6.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.6.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.6.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.6.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.6.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.6.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.6.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.6.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.6.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.6.output.dense.weight 	 Loaded
# text_branch.encoder.layer.6.output.dense.bias 	 Loaded
# text_branch.encoder.layer.6.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.6.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.7.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.7.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.7.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.7.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.7.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.7.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.7.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.7.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.7.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.7.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.7.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.7.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.7.output.dense.weight 	 Loaded
# text_branch.encoder.layer.7.output.dense.bias 	 Loaded
# text_branch.encoder.layer.7.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.7.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.8.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.8.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.8.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.8.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.8.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.8.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.8.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.8.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.8.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.8.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.8.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.8.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.8.output.dense.weight 	 Loaded
# text_branch.encoder.layer.8.output.dense.bias 	 Loaded
# text_branch.encoder.layer.8.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.8.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.9.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.9.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.9.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.9.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.9.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.9.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.9.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.9.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.9.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.9.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.9.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.9.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.9.output.dense.weight 	 Loaded
# text_branch.encoder.layer.9.output.dense.bias 	 Loaded
# text_branch.encoder.layer.9.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.9.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.10.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.10.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.10.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.10.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.10.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.10.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.10.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.10.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.10.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.10.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.10.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.10.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.10.output.dense.weight 	 Loaded
# text_branch.encoder.layer.10.output.dense.bias 	 Loaded
# text_branch.encoder.layer.10.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.10.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.11.attention.self.query.weight 	 Loaded
# text_branch.encoder.layer.11.attention.self.query.bias 	 Loaded
# text_branch.encoder.layer.11.attention.self.key.weight 	 Loaded
# text_branch.encoder.layer.11.attention.self.key.bias 	 Loaded
# text_branch.encoder.layer.11.attention.self.value.weight 	 Loaded
# text_branch.encoder.layer.11.attention.self.value.bias 	 Loaded
# text_branch.encoder.layer.11.attention.output.dense.weight 	 Loaded
# text_branch.encoder.layer.11.attention.output.dense.bias 	 Loaded
# text_branch.encoder.layer.11.attention.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.11.attention.output.LayerNorm.bias 	 Loaded
# text_branch.encoder.layer.11.intermediate.dense.weight 	 Loaded
# text_branch.encoder.layer.11.intermediate.dense.bias 	 Loaded
# text_branch.encoder.layer.11.output.dense.weight 	 Loaded
# text_branch.encoder.layer.11.output.dense.bias 	 Loaded
# text_branch.encoder.layer.11.output.LayerNorm.weight 	 Loaded
# text_branch.encoder.layer.11.output.LayerNorm.bias 	 Loaded
# text_branch.pooler.dense.weight 	 Loaded
# text_branch.pooler.dense.bias 	 Loaded
# text_transform.sequential.0.weight 	 Loaded
# text_transform.sequential.0.bias 	 Loaded
# text_transform.sequential.3.weight 	 Loaded
# text_transform.sequential.3.bias 	 Loaded
# text_projection.0.weight 	 Loaded
# text_projection.0.bias 	 Loaded
# text_projection.2.weight 	 Loaded
# text_projection.2.bias 	 Loaded
# audio_transform.sequential.0.weight 	 Loaded
# audio_transform.sequential.0.bias 	 Loaded
# audio_transform.sequential.3.weight 	 Loaded
# audio_transform.sequential.3.bias 	 Loaded
# audio_projection.0.weight 	 Loaded
# audio_projection.0.bias 	 Loaded
# audio_projection.2.weight 	 Loaded
# audio_projection.2.bias 	 Loaded
# ✅ CLAP loaded
# 📜 lyric character stats: median=1000  max=1000  hits-1000-cap=81/150
# 🎤 chorus detected for 145/150 tracks  (remainder fall back to first 300 chars)
# 🧠 IB-text · chorus ...
# 🧠 IB-text · multi-segment (K=4 chunks per track, mean-pooled) ...
#    IB-text-multi  [  1/150]
#    IB-text-multi  [ 25/150]
#    IB-text-multi  [ 50/150]
#    IB-text-multi  [ 75/150]
#    IB-text-multi  [100/150]
#    IB-text-multi  [125/150]
#    IB-text-multi  [150/150]
# 🎼 CLAP-text · chorus ...
# 🎼 CLAP-text · multi-segment ...
#    CLAP-text-multi [  1/150]
#    CLAP-text-multi [ 25/150]
#    CLAP-text-multi [ 50/150]
#    CLAP-text-multi [ 75/150]
#    CLAP-text-multi [100/150]
#    CLAP-text-multi [125/150]
#    CLAP-text-multi [150/150]
#   💾 text_ib_chorus         (150, 1024)
#   💾 text_ib_multi          (150, 1024)
#   💾 text_clap_chorus       (150, 512)
#   💾 text_clap_multi        (150, 512)
# ✅ lyric re-extraction complete (chorus + multi-segment)

# %%
# === CELL 7 — Encoder zoo: dict {name: (N, D) array} for ALL spaces ===
import os, numpy as np

EMB = dict(ORIG_EMB)   # start with the 6 originals

NEW_FILES = [
    # audio re-samplers (Cell 6)
    ("audio_ib_random",   "audio_ib_random.npy"),
    ("audio_ib_energy",   "audio_ib_energy.npy"),
    ("audio_mert_random", "audio_mert_random.npy"),
    ("audio_mert_energy", "audio_mert_energy.npy"),
    # lyric re-samplers (Cell 6b)
    ("text_ib_chorus",    "text_ib_chorus.npy"),
    ("text_ib_multi",     "text_ib_multi.npy"),
    ("text_clap_chorus",  "text_clap_chorus.npy"),
    ("text_clap_multi",   "text_clap_multi.npy"),
]
for name, fname in NEW_FILES:
    p = os.path.join(EMB_OUT, fname)
    if os.path.exists(p):
        EMB[name] = np.load(p).astype(np.float32)

# Order so audio block stays grouped, then image, then text
ENCODERS = [
    "audio_ib_orig", "audio_ib_random", "audio_ib_energy",
    "audio_mert_orig", "audio_mert_random", "audio_mert_energy",
    "image_ib", "image_clip",
    "text_ib", "text_ib_chorus", "text_ib_multi",
    "text_clap", "text_clap_chorus", "text_clap_multi",
]
ENCODERS = [e for e in ENCODERS if e in EMB]

print(f"Encoder zoo  ({len(ENCODERS)} spaces):")
for e in ENCODERS:
    print(f"  {e:22s}  {EMB[e].shape}")
# Out:
# Encoder zoo  (14 spaces):
#   audio_ib_orig           (150, 1024)
#   audio_ib_random         (150, 1024)
#   audio_ib_energy         (150, 1024)
#   audio_mert_orig         (150, 768)
#   audio_mert_random       (150, 768)
#   audio_mert_energy       (150, 768)
#   image_ib                (150, 1024)
#   image_clip              (150, 512)
#   text_ib                 (150, 1024)
#   text_ib_chorus          (150, 1024)
#   text_ib_multi           (150, 1024)
#   text_clap               (150, 512)
#   text_clap_chorus        (150, 512)
#   text_clap_multi         (150, 512)

# %%
# === CELL 8 — METHOD 1: K-means in each space, purity by every label scheme ===
# For each encoder, run KMeans(k=6) on L2-normalized features, then for each
# label scheme compute cluster purity (the dominant-label fraction averaged
# over clusters, weighted by cluster size).
import os, numpy as np, pandas as pd

K = 6
rows = []
for enc in ENCODERS:
    Xn = l2(EMB[enc])
    km = KMeans(n_clusters=K, n_init=20, random_state=SEED).fit(Xn)
    pred = km.labels_
    for lab in LABEL_COLS:
        true = metadata[lab].astype("category").cat.codes.values
        if metadata[lab].nunique() < 2:
            continue
        pur = cluster_purity(pred, true)
        # also baseline: most-frequent-label purity (chance for a single-cluster predictor)
        bp = metadata[lab].value_counts(normalize=True).iloc[0]
        rows.append({"encoder": enc, "label": lab,
                     "kmeans_purity": round(pur, 4),
                     "majority_baseline": round(bp, 4),
                     "lift_over_baseline": round(pur - bp, 4)})

m1 = pd.DataFrame(rows)
m1_pivot = m1.pivot(index="encoder", columns="label", values="kmeans_purity").loc[ENCODERS]
m1.to_csv(os.path.join(RES_OUT, "method1_kmeans_purity.csv"), index=False)

# heatmap fig
import matplotlib.pyplot as plt, seaborn as sns
fig, ax = plt.subplots(figsize=(11, 5.5))
sns.heatmap(m1_pivot, annot=True, fmt=".2f", cmap="viridis",
            cbar_kws={"label": "k-means cluster purity"}, ax=ax,
            vmin=0.15, vmax=max(0.5, m1_pivot.values.max()))
ax.set_title("Method 1 — K-means cluster purity by label scheme (k = 6)")
ax.set_ylabel(""); ax.set_xlabel("Label scheme")
plt.xticks(rotation=25, ha='right')
plt.tight_layout()
fig.savefig(os.path.join(FIG_OUT, "method1_purity_heatmap.png"), dpi=150)
plt.show()

# Best-label per encoder summary
print("Best-purity label per encoder:")
for enc in ENCODERS:
    sub = m1[m1.encoder == enc].sort_values("lift_over_baseline", ascending=False)
    if not sub.empty:
        top = sub.iloc[0]
        print(f"  {enc:22s} → {top.label:25s}  purity={top.kmeans_purity:.3f}  "
              f"baseline={top.majority_baseline:.3f}  lift={top.lift_over_baseline:+.3f}")
# Out:
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x7bbfd72372e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 1005, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 1187, in _make_controller_from_path
#     lib_controller = controller_class(
#                      ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/threadpoolctl.py", line 114, in __init__
#     self.dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/ctypes/__init__.py", line 379, in __init__
#     self._handle = _dlopen(self._name, mode)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: /usr/local/lib/python3.12/dist-packages/numpy.libs/libscipy_openblas64_-99b71e71.so: cannot open shared object file: No such file or directory
# Best-purity label per encoder:
#   audio_ib_orig          → label_contributor          purity=0.360  baseline=0.200  lift=+0.160
#   audio_ib_random        → label_emotion              purity=0.347  baseline=0.167  lift=+0.180
#   audio_ib_energy        → label_emotion              purity=0.367  baseline=0.167  lift=+0.200
#   audio_mert_orig        → label_contributor          purity=0.347  baseline=0.200  lift=+0.147
#   audio_mert_random      → label_emotion              purity=0.307  baseline=0.167  lift=+0.140
#   audio_mert_energy      → label_emotion              purity=0.313  baseline=0.167  lift=+0.147
#   image_ib               → label_emotion              purity=0.287  baseline=0.167  lift=+0.120
#   image_clip             → label_contributor          purity=0.347  baseline=0.200  lift=+0.147
#   text_ib                → label_contributor          purity=0.333  baseline=0.200  lift=+0.133
#   text_ib_chorus         → label_emotion              purity=0.273  baseline=0.167  lift=+0.107
#   text_ib_multi          → label_emotion              purity=0.307  baseline=0.167  lift=+0.140
#   text_clap              → label_emotion              purity=0.273  baseline=0.167  lift=+0.107
#   text_clap_chorus       → label_emotion              purity=0.287  baseline=0.167  lift=+0.120
#   text_clap_multi        → label_emotion              purity=0.340  baseline=0.167  lift=+0.173

# %%
# === CELL 9 — METHOD 2: Per-track nearest neighbors per encoder ===
import os, pandas as pd, numpy as np

K_NEIGHBORS = 5
DIAGNOSTIC_TRACKS = ["track_088", "track_027", "track_143", "track_055", "track_148"]
# m.A.A.d city, Bloom, Water, Hard Times, Wicked Game

tid2idx = {t: i for i, t in enumerate(metadata["track_id"])}
neighbors_full = []
diagnostic_lines = []

for enc in ENCODERS:
    nn = topk_neighbors(EMB[enc], k=K_NEIGHBORS, exclude_self=True)
    for i, row in enumerate(nn):
        for rank, j in enumerate(row, start=1):
            neighbors_full.append({
                "encoder": enc,
                "query_track": metadata.iloc[i]["track_id"],
                "query_song":  metadata.iloc[i]["song_title"],
                "query_emotion": metadata.iloc[i]["label_emotion"],
                "query_genre_top": metadata.iloc[i]["label_genre_top"],
                "rank": rank,
                "neighbor_track": metadata.iloc[j]["track_id"],
                "neighbor_song":  metadata.iloc[j]["song_title"],
                "neighbor_emotion": metadata.iloc[j]["label_emotion"],
                "neighbor_genre_top": metadata.iloc[j]["label_genre_top"],
                "same_emotion": metadata.iloc[j]["label_emotion"] == metadata.iloc[i]["label_emotion"],
                "same_genre":   metadata.iloc[j]["label_genre_top"] == metadata.iloc[i]["label_genre_top"],
            })

m2 = pd.DataFrame(neighbors_full)
m2.to_csv(os.path.join(RES_OUT, "method2_neighbors_full.csv"), index=False)

# fraction-same-emotion per encoder (a proxy for "this encoder clusters by emotion")
agg = m2.groupby("encoder").agg(
    frac_same_emotion=("same_emotion", "mean"),
    frac_same_genre=("same_genre", "mean"),
).round(3).loc[ENCODERS]
print("\n=== Top-K neighbor agreement with EACH labeling per encoder ===")
print(agg.to_string())

# Diagnostic-track listings
diagnostic_lines.append("=" * 78)
diagnostic_lines.append("DIAGNOSTIC TRACKS — top-5 nearest neighbors per encoder")
diagnostic_lines.append("=" * 78)
for tid in DIAGNOSTIC_TRACKS:
    if tid not in tid2idx: continue
    i = tid2idx[tid]
    md = metadata.iloc[i]
    diagnostic_lines.append(f"\n▶ {tid}  '{md.song_title}' by {md.artist_name}")
    diagnostic_lines.append(f"   true emotion = {md.label_emotion}    genre = {md.label_genre_top}")
    for enc in ENCODERS:
        nbrs = topk_neighbors(EMB[enc], k=K_NEIGHBORS, exclude_self=True)[i]
        names = [f"{metadata.iloc[j].song_title[:20]} ({metadata.iloc[j].label_emotion[:8]}/"
                 f"{metadata.iloc[j].label_genre_top[:8]})"
                 for j in nbrs]
        diagnostic_lines.append(f"   {enc:22s} → " + " | ".join(names))

diag_path = os.path.join(RES_OUT, "method2_diagnostic_neighbors.txt")
with open(diag_path, "w") as f: f.write("\n".join(diagnostic_lines))
print(f"\n💾 saved {diag_path}")
print("\nFirst diagnostic track preview:")
print("\n".join(diagnostic_lines[3:18]))
# Out:
# === Top-K neighbor agreement with EACH labeling per encoder ===
#                    frac_same_emotion  frac_same_genre
# encoder
# audio_ib_orig                  0.220            0.363
# audio_ib_random                0.216            0.332
# audio_ib_energy                0.233            0.343
# audio_mert_orig                0.221            0.303
# audio_mert_random              0.237            0.301
# audio_mert_energy              0.233            0.295
# image_ib                       0.191            0.300
# image_clip                     0.188            0.307
# text_ib                        0.188            0.241
# text_ib_chorus                 0.177            0.212
# text_ib_multi                  0.221            0.268
# text_clap                      0.199            0.233
# text_clap_chorus               0.187            0.225
# text_clap_multi                0.221            0.247
#
# 💾 saved /content/drive/MyDrive/DL_Project_2026/Explorations 2.0/run_2026-05-06_06-08/results/method2_diagnostic_neighbors.txt
#
# First diagnostic track preview:
#
# ▶ track_088  'm.A.A.d city' by Kendrick Lamar, MC Eiht
#    true emotion = Tension, Threat & Aggression    genre = Hip-Hop
#    audio_ib_orig          → Industry Baby (Vital & /Hip-Hop) | I Don't Fuck With Yo (Tension,/Hip-Hop) | In My Room (Dreamine/R&B) | Champion (Vital & /Hip-Hop) | I THINK (Tender &/R&B)
#    audio_ib_random        → I Don't Fuck With Yo (Tension,/Hip-Hop) | Industry Baby (Vital & /Hip-Hop) | Believer (Tension,/Rock) | Champion (Vital & /Hip-Hop) | Risky (Dreamine/Rock)
#    audio_ib_energy        → I Don't Fuck With Yo (Tension,/Hip-Hop) | Industry Baby (Vital & /Hip-Hop) | Champion (Vital & /Hip-Hop) | In My Room (Dreamine/R&B) | I THINK (Tender &/R&B)
#    audio_mert_orig        → Red Eye (Dreamine/Electron) | Believer (Tension,/Rock) | Are You Bored Yet (f (Tender &/Rock) | Industry Baby (Vital & /Hip-Hop) | Oscar Winning Tears (Awe, Bea/Jazz)
#    audio_mert_random      → Red Eye (Dreamine/Electron) | Believer (Tension,/Rock) | Are You Bored Yet (f (Tender &/Rock) | This Time (Tender &/R&B) | Oscar Winning Tears (Awe, Bea/Jazz)
#    audio_mert_energy      → Champion (Vital & /Hip-Hop) | Believer (Tension,/Rock) | Are You Bored Yet (f (Tender &/Rock) | I Don't Fuck With Yo (Tension,/Hip-Hop) | Industry Baby (Vital & /Hip-Hop)
#    image_ib               → Best Part (Tender &/R&B) | In My Room (Dreamine/R&B) | I THINK (Tender &/R&B) | Stay (Awe, Bea/Pop) | Juna (Tender &/Pop)
#    image_clip             → Best Part (Tender &/R&B) | Champion (Vital & /Hip-Hop) | Fix You (Awe, Bea/Rock) | I THINK (Tender &/R&B) | Hot Body (Tender &/Pop)
#    text_ib                → My Generation (Tension,/Rock) | Lovers Rock (Tender &/Rock) | 1999 (Vital & /Pop) | Industry Baby (Vital & /Hip-Hop) | Hard Times (Vital & /Pop)
#    text_ib_chorus         → Last Call (Awe, Bea/Pop) | Animals (Tension,/Rock) | Karma Police (Awe, Bea/Rock) | Sparks (Sadness,/Rock) | How to Disappear Com (Sadness,/Rock)
#    text_ib_multi          → Industry Baby (Vital & /Hip-Hop) | Why I Love You (Dreamine/Hip-Hop) | Last Call (Awe, Bea/Pop) | I Don't Fuck With Yo (Tension,/Hip-Hop) | IS THIS A CULT? (Tension,/Rock)
#    text_clap              → My Generation (Tension,/Rock) | Industry Baby (Vital & /Hip-Hop) | Holocene (Dreamine/Folk) | Happy (Vital & /Pop) | Bad Guy (Tension,/Pop)
#    text_clap_chorus       → Valder Fields (Awe, Bea/Folk) | Tears and Rain (Sadness,/Folk) | Everybody Talks (Vital & /Rock) | TIT FOR TAT (Tension,/Pop) | Say Something (Sadness,/Folk)

# %%
# === CELL 10 — METHOD 3: Silhouette by alternative labelings ===
# For each encoder × label scheme, compute silhouette (cosine, on L2-normalized).
# Whichever labeling gives the highest silhouette is what the encoder is genuinely
# organizing by.
import os, numpy as np, pandas as pd
from sklearn.metrics import silhouette_score

rows = []
for enc in ENCODERS:
    Xn = l2(EMB[enc])
    for lab in LABEL_COLS:
        codes = metadata[lab].astype("category").cat.codes.values
        if metadata[lab].nunique() < 2:
            continue
        try:
            s = silhouette_score(Xn, codes, metric="cosine")
        except Exception:
            s = np.nan
        rows.append({"encoder": enc, "label": lab, "silhouette": round(s, 4)})

m3 = pd.DataFrame(rows)
m3_pivot = m3.pivot(index="encoder", columns="label", values="silhouette").loc[ENCODERS]
m3.to_csv(os.path.join(RES_OUT, "method3_silhouette_heatmap.csv"), index=False)

import matplotlib.pyplot as plt, seaborn as sns
vmax = max(0.10, m3_pivot.values.max())
vmin = min(-0.02, m3_pivot.values.min())
fig, ax = plt.subplots(figsize=(11, 5.5))
sns.heatmap(m3_pivot, annot=True, fmt=".3f", cmap="RdBu_r", center=0,
            vmin=vmin, vmax=vmax, cbar_kws={"label": "silhouette (cosine)"}, ax=ax)
ax.set_title("Method 3 — Silhouette by labeling scheme  (>0 = real cluster signal)")
ax.set_ylabel(""); ax.set_xlabel("Label scheme")
plt.xticks(rotation=25, ha='right')
plt.tight_layout()
fig.savefig(os.path.join(FIG_OUT, "method3_silhouette_heatmap.png"), dpi=150)
plt.show()

print("\nBest labeling per encoder (highest silhouette):")
for enc in ENCODERS:
    sub = m3[m3.encoder == enc].sort_values("silhouette", ascending=False)
    if not sub.empty:
        top = sub.iloc[0]
        print(f"  {enc:22s} → {top.label:25s} silhouette = {top.silhouette:+.3f}")
# Out:
# Best labeling per encoder (highest silhouette):
#   audio_ib_orig          → label_contributor         silhouette = -0.037
#   audio_ib_random        → label_contributor         silhouette = -0.026
#   audio_ib_energy        → label_contributor         silhouette = -0.033
#   audio_mert_orig        → label_contributor         silhouette = -0.046
#   audio_mert_random      → label_contributor         silhouette = -0.049
#   audio_mert_energy      → label_contributor         silhouette = -0.047
#   image_ib               → label_contributor         silhouette = -0.026
#   image_clip             → label_contributor         silhouette = -0.025
#   text_ib                → label_contributor         silhouette = -0.022
#   text_ib_chorus         → label_contributor         silhouette = -0.032
#   text_ib_multi          → label_contributor         silhouette = -0.024
#   text_clap              → label_contributor         silhouette = -0.063
#   text_clap_chorus       → label_contributor         silhouette = -0.041
#   text_clap_multi        → label_contributor         silhouette = -0.066

# %%
# === CELL 11 — METHOD 4: Cross-encoder disagreement (neighbor-Jaccard) ===
# For each pair of encoders, compute per-track Jaccard between their top-K
# nearest-neighbor sets.  Low Jaccard = the two encoders see different
# neighborhoods for that track.
import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns

K_NB = 5

# Pre-compute neighbor sets for each encoder
NB_SETS = {enc: [set(row) for row in topk_neighbors(EMB[enc], k=K_NB, exclude_self=True)]
           for enc in ENCODERS}

# Pairwise mean Jaccard heatmap
M = np.zeros((len(ENCODERS), len(ENCODERS)))
for a, ea in enumerate(ENCODERS):
    for b, eb in enumerate(ENCODERS):
        if b < a: continue
        scores = [len(NB_SETS[ea][i] & NB_SETS[eb][i]) /
                  max(1, len(NB_SETS[ea][i] | NB_SETS[eb][i]))
                  for i in range(N)]
        M[a, b] = M[b, a] = np.mean(scores)

dis = pd.DataFrame(M, index=ENCODERS, columns=ENCODERS).round(3)
dis.to_csv(os.path.join(RES_OUT, "method4_jaccard_matrix.csv"))

fig, ax = plt.subplots(figsize=(8.5, 7.5))
sns.heatmap(dis, annot=True, fmt=".2f", cmap="YlGnBu",
            cbar_kws={"label": f"mean top-{K_NB} neighbor Jaccard"}, ax=ax)
ax.set_title(f"Method 4 — Cross-encoder neighbor agreement (top-{K_NB} Jaccard, n=150)")
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
fig.savefig(os.path.join(FIG_OUT, "method4_jaccard_heatmap.png"), dpi=150)
plt.show()

# Top-K most-disagreed tracks per pair (pairs of interest)
PAIRS = [("audio_ib_orig","audio_mert_orig"),
         ("audio_ib_orig","audio_ib_random"),
         ("audio_ib_orig","audio_ib_energy"),
         ("image_ib","image_clip"),
         ("text_ib","text_clap")]
disag_top = []
for ea, eb in PAIRS:
    if ea not in ENCODERS or eb not in ENCODERS: continue
    per_track = []
    for i in range(N):
        j = len(NB_SETS[ea][i] & NB_SETS[eb][i]) / max(1, len(NB_SETS[ea][i] | NB_SETS[eb][i]))
        per_track.append((i, j))
    per_track.sort(key=lambda x: x[1])
    for rank, (i, j) in enumerate(per_track[:10], start=1):
        md = metadata.iloc[i]
        disag_top.append({
            "pair": f"{ea} vs {eb}", "rank": rank, "jaccard": round(j, 3),
            "track_id": md.track_id, "song": md.song_title,
            "emotion": md.label_emotion, "genre": md.label_genre_top,
        })
disag_df = pd.DataFrame(disag_top)
disag_df.to_csv(os.path.join(RES_OUT, "method4_disagreement_topK.csv"), index=False)
print("\nTop-10 most-disagreed tracks per encoder pair:")
for pair, sub in disag_df.groupby("pair"):
    print(f"\n  {pair}")
    for _, r in sub.iterrows():
        print(f"     [{r['rank']:2d}]  J={r.jaccard:.2f}  {r.track_id}  '{r.song[:30]}'  "
              f"({r.emotion[:10]} / {r.genre[:10]})")
# Out:
# Top-10 most-disagreed tracks per encoder pair:
#
#   audio_ib_orig vs audio_ib_energy
#      [ 1]  J=0.00  track_005  ':) '  (Vital & Jo / Pop)
#      [ 2]  J=0.00  track_013  'Anchor'  (Dreaminess / Folk)
#      [ 3]  J=0.00  track_016  'Another Day of Sun'  (Vital & Jo / Jazz)
#      [ 4]  J=0.00  track_093  'Myth'  (Dreaminess / Pop)
#      [ 5]  J=0.00  track_096  'Nothing'  (Tender & I / Folk)
#      [ 6]  J=0.00  track_111  'Run to me'  (Tender & I / Pop)
#      [ 7]  J=0.00  track_132  'Thinking Clean'  (Dreaminess / R&B)
#      [ 8]  J=0.11  track_019  'Bad Guy'  (Tension, T / Pop)
#      [ 9]  J=0.11  track_022  'Believer'  (Tension, T / Rock)
#      [10]  J=0.11  track_026  'Bloody Samaritan (Remix)'  (Vital & Jo / Pop)
#
#   audio_ib_orig vs audio_ib_random
#      [ 1]  J=0.00  track_007  'A Trick of the light'  (Dreaminess / Folk)
#      [ 2]  J=0.00  track_010  'Air Supply'  (Dreaminess / Rock)
#      [ 3]  J=0.00  track_016  'Another Day of Sun'  (Vital & Jo / Jazz)
#      [ 4]  J=0.00  track_029  'By This River'  (Awe, Beaut / Ambient)
#      [ 5]  J=0.00  track_039  'Cruel Summer'  (Vital & Jo / Pop)
#      [ 6]  J=0.00  track_071  'If'  (Tender & I / Pop)
#      [ 7]  J=0.00  track_078  'Juna'  (Tender & I / Pop)
#      [ 8]  J=0.00  track_131  'The Way Things Go'  (Sadness, L / Rock)
#      [ 9]  J=0.00  track_132  'Thinking Clean'  (Dreaminess / R&B)
#      [10]  J=0.11  track_005  ':) '  (Vital & Jo / Pop)
#
#   audio_ib_orig vs audio_mert_orig
#      [ 1]  J=0.00  track_001  '$0'  (Sadness, L / Folk)
#      [ 2]  J=0.00  track_006  'A Pearl'  (Tension, T / Rock)
#      [ 3]  J=0.00  track_007  'A Trick of the light'  (Dreaminess / Folk)
#      [ 4]  J=0.00  track_008  'A Whiter Shade of Pale'  (Awe, Beaut / Rock)
#      [ 5]  J=0.00  track_010  'Air Supply'  (Dreaminess / Rock)
#      [ 6]  J=0.00  track_011  'All By Myself'  (Sadness, L / Pop)
#      [ 7]  J=0.00  track_012  'Amazing Grace'  (Awe, Beaut / Classical)
#      [ 8]  J=0.00  track_016  'Another Day of Sun'  (Vital & Jo / Jazz)
#      [ 9]  J=0.00  track_018  'Au Pays du Cocaine'  (Sadness, L / Folk)
#      [10]  J=0.00  track_021  'Before I Sleep'  (Tension, T / Folk)
#
#   image_ib vs image_clip
#      [ 1]  J=0.00  track_002  '12:45 - Stripped'  (Sadness, L / Pop)
#      [ 2]  J=0.00  track_004  '360'  (Vital & Jo / Pop)
#      [ 3]  J=0.00  track_007  'A Trick of the light'  (Dreaminess / Folk)
#      [ 4]  J=0.00  track_009  'Aint It Funny '  (Tension, T / Metal)
#      [ 5]  J=0.00  track_012  'Amazing Grace'  (Awe, Beaut / Classical)
#      [ 6]  J=0.00  track_014  'Anemone'  (Tension, T / Rock)
#      [ 7]  J=0.00  track_017  'Are You Bored Yet (feat. Clair'  (Tender & I / Rock)
#      [ 8]  J=0.00  track_019  'Bad Guy'  (Tension, T / Pop)
#      [ 9]  J=0.00  track_024  'Better Things'  (Vital & Jo / Pop)
#      [10]  J=0.00  track_031  'Champion'  (Vital & Jo / Hip-Hop)
#
#   text_ib vs text_clap
#      [ 1]  J=0.00  track_001  '$0'  (Sadness, L / Folk)
#      [ 2]  J=0.00  track_002  '12:45 - Stripped'  (Sadness, L / Pop)
#      [ 3]  J=0.00  track_003  '1999'  (Vital & Jo / Pop)
#      [ 4]  J=0.00  track_004  '360'  (Vital & Jo / Pop)
#      [ 5]  J=0.00  track_005  ':) '  (Vital & Jo / Pop)
#      [ 6]  J=0.00  track_006  'A Pearl'  (Tension, T / Rock)
#      [ 7]  J=0.00  track_008  'A Whiter Shade of Pale'  (Awe, Beaut / Rock)
#      [ 8]  J=0.00  track_009  'Aint It Funny '  (Tension, T / Metal)
#      [ 9]  J=0.00  track_010  'Air Supply'  (Dreaminess / Rock)
#      [10]  J=0.00  track_011  'All By Myself'  (Sadness, L / Pop)

# %%
# === CELL 12 — METHOD 5: Block-sorted 150×150 similarity heatmaps ===
# For each encoder, render the 150x150 cosine matrix sorted by each label
# scheme. The label that gives the cleanest block-diagonal is what that
# encoder is most strongly responding to.
import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt, seaborn as sns

# Compute "block contrast" for each (encoder × label): mean within-block cosine
# minus mean between-block cosine. Bigger = stronger block-diagonal structure.
def block_contrast(sim, codes):
    """sim is (N,N) cosine; codes is (N,) int labels."""
    in_mask  = (codes[:, None] == codes[None, :]).astype(bool)
    np.fill_diagonal(in_mask, False)         # exclude self-pairs
    out_mask = ~in_mask
    np.fill_diagonal(out_mask, False)
    in_mean  = sim[in_mask].mean()  if in_mask.any()  else np.nan
    out_mean = sim[out_mask].mean() if out_mask.any() else np.nan
    return in_mean, out_mean, in_mean - out_mean

# Pick which encoders to RENDER (avoid 60-figure explosion). All encoders are
# scored, but we only render heatmaps for a curated short list.
RENDER_ENC = ["audio_ib_orig", "audio_mert_orig", "image_ib", "image_clip", "text_ib"]
RENDER_ENC = [e for e in RENDER_ENC if e in ENCODERS]

scores = []
for enc in ENCODERS:
    sim = cos_sim(EMB[enc])
    for lab in LABEL_COLS:
        codes = metadata[lab].astype("category").cat.codes.values
        if metadata[lab].nunique() < 2: continue
        ib, ob, contrast = block_contrast(sim, codes)
        scores.append({"encoder": enc, "label": lab,
                       "within_block_mean": round(ib, 4),
                       "between_block_mean": round(ob, 4),
                       "block_contrast": round(contrast, 4)})

m5 = pd.DataFrame(scores)
m5.to_csv(os.path.join(RES_OUT, "method5_blocksort_summary.csv"), index=False)

# Render block-sorted heatmaps for the curated encoders × all labels
for enc in RENDER_ENC:
    sim = cos_sim(EMB[enc])
    fig, axes = plt.subplots(2, 3, figsize=(14, 9))
    fig.suptitle(f"Method 5 — Block-sorted cosine matrix · encoder = {enc}", fontsize=13)
    for ax, lab in zip(axes.flat, LABEL_COLS):
        if metadata[lab].nunique() < 2:
            ax.axis("off"); continue
        order = np.argsort(metadata[lab].astype("category").cat.codes.values)
        block = sim[np.ix_(order, order)]
        sns.heatmap(block, ax=ax, cmap="viridis", cbar=False, square=True,
                    xticklabels=False, yticklabels=False,
                    vmin=np.percentile(block, 5), vmax=np.percentile(block, 95))
        sub = m5[(m5.encoder == enc) & (m5.label == lab)].iloc[0]
        ax.set_title(f"{lab.replace('label_','')}  (Δ = {sub.block_contrast:+.3f})", fontsize=10)
    for ax in axes.flat[len(LABEL_COLS):]:
        ax.axis("off")
    plt.tight_layout()
    fig.savefig(os.path.join(FIG_OUT, f"method5_blocksort_{enc}.png"), dpi=130, bbox_inches='tight')
    plt.show()
    plt.close()

# Best label per encoder by block contrast
print("\nBest labeling per encoder by block contrast:")
for enc in ENCODERS:
    sub = m5[m5.encoder == enc].sort_values("block_contrast", ascending=False)
    if not sub.empty:
        top = sub.iloc[0]
        print(f"  {enc:22s} → {top.label:25s}  Δ={top.block_contrast:+.3f}  "
              f"(within={top.within_block_mean:+.3f}  between={top.between_block_mean:+.3f})")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# === CELL V-A1 — V-A regression (anchor-based, leave-one-out R²) ===
# Map each track's emotion category to a Russell-circumplex anchor (V, A) point,
# then fit a linear regression from each encoder's embedding to (V, A).
# Score with leave-one-out cross-validation R².
#
# Caveat: Y has only 6 distinct values (one per emotion category), so this
# probe measures category separability projected onto V-A axes, not free
# continuous valence-arousal estimation.  We are explicit about this limitation
# both here and in any downstream slide that uses these numbers.
import os, numpy as np, pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import LeaveOneOut, cross_val_predict
from sklearn.metrics import r2_score

# Russell circumplex anchors (matched to nb06 Cell 2)
VA_ANCHORS = {
    "Vital & Joyful":                    ( 0.85,  0.85),
    "Tension, Threat & Aggression":      (-0.80,  0.80),
    "Sadness, Loss & Lament":            (-0.75, -0.75),
    "Tender & Intimacy":                 ( 0.70, -0.70),
    "Awe, Beauty & Transcendence":       ( 0.90,  0.10),
    "Dreaminess, Curiosity & Ambiguity": ( 0.00,  0.00),
}

# Build (N, 2) anchor target Y
y_va = np.array([VA_ANCHORS[e] for e in metadata["label_emotion"]], dtype=np.float32)
print(f"V-A target Y shape: {y_va.shape}   (6 unique anchor positions, 25 tracks each)")

va_rows = []
for enc in ENCODERS:
    Xn = l2(EMB[enc])
    # leave-one-out cross-validated predictions
    y_pred = cross_val_predict(LinearRegression(), Xn, y_va, cv=LeaveOneOut())
    r2_v   = r2_score(y_va[:, 0], y_pred[:, 0])
    r2_a   = r2_score(y_va[:, 1], y_pred[:, 1])
    r2_tot = r2_score(y_va,        y_pred,        multioutput="uniform_average")
    # Mean Euclidean distance from prediction to true anchor (lower = better)
    err = np.linalg.norm(y_pred - y_va, axis=1).mean()
    va_rows.append({
        "encoder":   enc,
        "R2_valence":  round(float(r2_v),   4),
        "R2_arousal":  round(float(r2_a),   4),
        "R2_overall":  round(float(r2_tot), 4),
        "mean_err":    round(float(err),    4),
    })

va_df = pd.DataFrame(va_rows).sort_values("R2_overall", ascending=False).reset_index(drop=True)
va_df.to_csv(os.path.join(RES_OUT, "VA1_regression_loocv.csv"), index=False)

print()
print("V-A regression — leave-one-out R² per encoder")
print("=" * 78)
print(va_df.to_string(index=False))

# Quick interpretation lines
top = va_df.iloc[0]
print()
print(f"BEST encoder: {top.encoder}  → R² overall = {top.R2_overall:+.3f}")
ref = 0.10
verdict = ("✅ meaningful V-A signal" if top.R2_overall > ref
           else "⚠ weak V-A signal — barely above chance")
print(f"Verdict (rule of thumb: R² > 0.10 = real, > 0.30 = strong):  {verdict}")
# Out:
# V-A target Y shape: (150, 2)   (6 unique anchor positions, 25 tracks each)
#
# V-A regression — leave-one-out R² per encoder
# ==============================================================================
#           encoder  R2_valence  R2_arousal  R2_overall  mean_err
#           text_ib     -0.2753     -0.0094     -0.1424    0.9184
#     text_ib_multi     -0.2837     -0.2881     -0.2859    0.9667
#    text_ib_chorus     -0.6840     -0.4202     -0.5521    1.0899
#        image_clip     -0.5481     -0.6230     -0.5855    1.0913
#   audio_mert_orig     -0.7621     -0.6467     -0.7044    1.1136
#          image_ib     -0.9014     -0.5732     -0.7373    1.1694
# audio_mert_energy     -0.6726     -0.8872     -0.7799    1.1337
# audio_mert_random     -0.8489     -0.7462     -0.7975    1.1281
#     audio_ib_orig     -1.1715     -0.8943     -1.0329    1.2207
#   audio_ib_energy     -1.5740     -0.6629     -1.1184    1.2512
#   audio_ib_random     -0.8690     -1.4871     -1.1780    1.2330
#   text_clap_multi     -1.7195     -1.3009     -1.5102    1.3620
#  text_clap_chorus     -1.5134     -2.1186     -1.8160    1.4224
#         text_clap     -3.1136     -1.1629     -2.1383    1.5205
#
# BEST encoder: text_ib  → R² overall = -0.142
# Verdict (rule of thumb: R² > 0.10 = real, > 0.30 = strong):  ⚠ weak V-A signal — barely above chance

# %%
# === CELL V-A2 — V-A pre/post side-by-side circumplex ===
# For two encoder pairs (audio_ib_orig vs audio_ib_energy ; text_clap vs
# text_clap_chorus), render the V-A circumplex with anchor positions plus
# each encoder's predicted centroid PER emotion category.  The closer each
# colored centroid is to its anchor (white star), the better the encoder
# represents that emotion under the V-A probe.
import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import LeaveOneOut, cross_val_predict

# Color per emotion category (matches deck conventions)
EMO_COLORS = {
    "Vital & Joyful":                    "#F4A300",
    "Tender & Intimacy":                 "#E76F51",
    "Awe, Beauty & Transcendence":       "#8B5CF6",
    "Tension, Threat & Aggression":      "#C03221",
    "Sadness, Loss & Lament":            "#2563EB",
    "Dreaminess, Curiosity & Ambiguity": "#0EA5E9",
}

PAIRS = [
    ("AUDIO  •  energy-peak vs original",  "audio_ib_orig",  "audio_ib_energy"),
    ("TEXT   •  chorus vs original",       "text_clap",      "text_clap_chorus"),
]

def predict_va(X, y):
    """Leave-one-out V-A predictions for one encoder space."""
    return cross_val_predict(LinearRegression(), l2(X), y, cv=LeaveOneOut())

def category_centroids(y_pred, labels):
    """Mean predicted (V, A) per emotion category."""
    out = {}
    for emo in VA_ANCHORS.keys():
        idx = np.where(labels == emo)[0]
        if len(idx):
            out[emo] = y_pred[idx].mean(axis=0)
    return out

emo_labels = metadata["label_emotion"].values

for pair_title, enc_pre, enc_post in PAIRS:
    if enc_pre not in EMB or enc_post not in EMB:
        print(f"Skipping {pair_title}: encoders not in zoo")
        continue

    pred_pre  = predict_va(EMB[enc_pre],  y_va)
    pred_post = predict_va(EMB[enc_post], y_va)
    cen_pre   = category_centroids(pred_pre,  emo_labels)
    cen_post  = category_centroids(pred_post, emo_labels)

    # Mean L2 error per anchor — for the panel subtitle
    err_pre  = np.mean([np.linalg.norm(np.array(cen_pre[e])  - VA_ANCHORS[e]) for e in cen_pre])
    err_post = np.mean([np.linalg.norm(np.array(cen_post[e]) - VA_ANCHORS[e]) for e in cen_post])

    fig, axes = plt.subplots(1, 2, figsize=(11.5, 5.6))
    for ax, (label, cen, err, enc_name) in zip(
        axes,
        [("PRE  (original)",  cen_pre,  err_pre,  enc_pre),
         ("POST (re-sampled)", cen_post, err_post, enc_post)]
    ):
        # Russell circle + axes
        circle = plt.Circle((0, 0), 1.0, fill=False, color="#888", lw=1.2)
        ax.add_patch(circle)
        ax.axhline(0, color="#888", lw=0.6); ax.axvline(0, color="#888", lw=0.6)
        # Anchor stars (white interior, category color edge)
        for emo, (vx, vy) in VA_ANCHORS.items():
            ax.scatter(vx, vy, s=300, marker="*", color="white",
                       edgecolors=EMO_COLORS[emo], linewidth=2.0, zorder=4)
            ax.annotate(emo.split(",")[0].split(" &")[0], (vx, vy),
                        xytext=(8, -2), textcoords="offset points",
                        fontsize=8, color=EMO_COLORS[emo], fontweight="bold")
        # Predicted centroids (filled circles)
        for emo, (vx, vy) in cen.items():
            ax.scatter(vx, vy, s=160, color=EMO_COLORS[emo],
                       edgecolors="white", linewidth=1.2, zorder=5)
            # Error vector from prediction → anchor
            ax_anchor = VA_ANCHORS[emo]
            ax.plot([vx, ax_anchor[0]], [vy, ax_anchor[1]],
                    color=EMO_COLORS[emo], lw=1.0, alpha=0.45, linestyle="--")
        ax.set_xlim(-1.20, 1.20); ax.set_ylim(-1.20, 1.20)
        ax.set_aspect("equal"); ax.set_xlabel("Valence"); ax.set_ylabel("Arousal")
        ax.set_title(f"{label}  ·  {enc_name}\nmean anchor error = {err:+.3f}",
                     fontsize=11)
        ax.grid(alpha=0.25)

    fig.suptitle(f"V-A predicted centroids — {pair_title}", fontsize=13, y=1.00)
    plt.tight_layout()
    fname = f"VA2_pre_post_{enc_pre}_vs_{enc_post}.png"
    fig.savefig(os.path.join(FIG_OUT, fname), dpi=160, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"💾 wrote {fname}   (pre err = {err_pre:.3f}  →  post err = {err_post:.3f})")

# ALSO — bar chart: V-A R² per encoder, sorted, with pre/post pairs grouped
import seaborn as sns
order = ENCODERS
fig, ax = plt.subplots(figsize=(11, 5.0))
heights = [va_df.set_index("encoder").loc[e, "R2_overall"] for e in order]
bar_colors = []
for e in order:
    if e.startswith("audio_ib"):  bar_colors.append("#E76F51")
    elif e.startswith("audio_mert"): bar_colors.append("#F4A300")
    elif e.startswith("image"):   bar_colors.append("#2563EB")
    elif e.startswith("text"):    bar_colors.append("#0F766E")
    else: bar_colors.append("#888")
bars = ax.barh(order, heights, color=bar_colors, edgecolor="none")
for bar, h in zip(bars, heights):
    ax.text(h + 0.005 if h >= 0 else h - 0.005,
            bar.get_y() + bar.get_height()/2, f"{h:+.3f}",
            va="center", ha="left" if h >= 0 else "right",
            fontsize=10, color="#1F2937")
ax.axvline(0, color="black", lw=0.7)
ax.axvline(0.10, color="#888", lw=0.7, linestyle="--")
ax.text(0.105, len(order)-0.3, "  R² > 0.10 = meaningful", color="#666", fontsize=9, va="top")
ax.invert_yaxis()
ax.set_xlabel("Leave-one-out V-A R² (overall)")
ax.set_title("V-A regression R² per encoder  ·  anchor-based, LOO-CV  ·  bar = predictive power on V-A axes")
ax.grid(axis="x", alpha=0.3)
plt.tight_layout()
fig.savefig(os.path.join(FIG_OUT, "VA2_R2_bar_per_encoder.png"), dpi=160, bbox_inches="tight")
plt.show()
plt.close(fig)
print("💾 wrote VA2_R2_bar_per_encoder.png")
# Out:
# 💾 wrote VA2_pre_post_audio_ib_orig_vs_audio_ib_energy.png   (pre err = 0.745  →  post err = 0.779)
# 💾 wrote VA2_pre_post_text_clap_vs_text_clap_chorus.png   (pre err = 0.969  →  post err = 0.795)
# 💾 wrote VA2_R2_bar_per_encoder.png

# %%
# === CELL 13 — Cross-method summary + write summary.md ===
import os, pandas as pd, numpy as np

# Reload everything from disk so this cell is independently re-runnable
m1 = pd.read_csv(os.path.join(RES_OUT, "method1_kmeans_purity.csv"))
m3 = pd.read_csv(os.path.join(RES_OUT, "method3_silhouette_heatmap.csv"))
m4 = pd.read_csv(os.path.join(RES_OUT, "method4_jaccard_matrix.csv"), index_col=0)
m5 = pd.read_csv(os.path.join(RES_OUT, "method5_blocksort_summary.csv"))

lines = []
lines.append(f"# Exploration run · {RUN_STAMP}")
lines.append("")
lines.append(f"- N tracks: **{N}**")
lines.append(f"- Encoder spaces analysed: **{len(ENCODERS)}**  ({', '.join(ENCODERS)})")
lines.append(f"- Label schemes: **{len(LABEL_COLS)}**  ({', '.join(c.replace('label_','') for c in LABEL_COLS)})")
lines.append(f"- Re-extraction: **{'enabled' if RUN_REEXTRACT else 'disabled'}**  (K=5 clips per track)")
lines.append("")

# 1. What does each encoder organize by? (silhouette + block contrast vote)
lines.append("## What does each encoder actually organize by?")
lines.append("Per encoder, we report the top label scheme by silhouette and by block contrast.  When both methods agree, that's a strong signal.")
lines.append("")
lines.append("| Encoder | Top label by silhouette | silhouette | Top label by block contrast | Δ |")
lines.append("|---|---|---|---|---|")
for enc in ENCODERS:
    s_top = m3[m3.encoder == enc].sort_values("silhouette", ascending=False).iloc[0]
    b_top = m5[m5.encoder == enc].sort_values("block_contrast", ascending=False).iloc[0]
    lines.append(f"| `{enc}` | {s_top.label.replace('label_','')} | {s_top.silhouette:+.3f} | "
                 f"{b_top.label.replace('label_','')} | {b_top.block_contrast:+.3f} |")
lines.append("")

# 2. Did re-sampling change things?
if RUN_REEXTRACT:
    lines.append("## Did the new audio + lyric sampling change anything?")
    lines.append("Compare the silhouette by emotion across the three audio_ib variants and three audio_mert variants:")
    lines.append("")
    for fam in ["audio_ib", "audio_mert", "text_ib", "text_clap"]:
        variants = [e for e in ENCODERS if e.startswith(fam)]
        if len(variants) < 2: continue
        lines.append(f"### {fam}")
        lines.append("| Variant | silhouette by emotion | silhouette by genre_top | Δ block-contrast emotion |")
        lines.append("|---|---|---|---|")
        for v in variants:
            se = m3[(m3.encoder == v) & (m3.label == "label_emotion")].iloc[0].silhouette
            sg = m3[(m3.encoder == v) & (m3.label == "label_genre_top")].iloc[0].silhouette
            be = m5[(m5.encoder == v) & (m5.label == "label_emotion")].iloc[0].block_contrast
            lines.append(f"| `{v}` | {se:+.3f} | {sg:+.3f} | {be:+.3f} |")
        lines.append("")

# 3. Does ANY modality match emotion labels?
lines.append("## Does any modality align with our subjective emotional labeling?")
emo = m3[m3.label == "label_emotion"].sort_values("silhouette", ascending=False)
lines.append("| Encoder | silhouette by emotion |")
lines.append("|---|---|")
for _, r in emo.iterrows():
    lines.append(f"| `{r.encoder}` | {r.silhouette:+.3f} |")
lines.append("")
top_emo = emo.iloc[0]
lines.append(f"**Best encoder for emotion: `{top_emo.encoder}` with silhouette {top_emo.silhouette:+.3f}.**")
ref = 0.10
verdict = "✅ meaningful cluster signal" if top_emo.silhouette > ref else (
          "⚠ weak signal — close to random" if top_emo.silhouette > 0 else
          "❌ no meaningful clustering by emotion")
lines.append(f"Interpretation: {verdict} (rule of thumb: silhouette > 0.10 = real clustering, > 0.25 = strong).")
lines.append("")

# 4. Which pairs of encoders disagree most about neighborhoods?
lines.append("## Cross-encoder disagreement (top-5 neighbor Jaccard)")
lines.append("Lower = encoders see different things.")
lines.append("")
flat = []
encs = m4.index.tolist()
for i, a in enumerate(encs):
    for b in encs[i+1:]:
        flat.append((a, b, m4.loc[a, b]))
flat.sort(key=lambda x: x[2])
lines.append("| Encoder pair | Jaccard |")
lines.append("|---|---|")
for a, b, j in flat[:10]:
    lines.append(f"| `{a}`  ×  `{b}` | {j:.2f} |")
lines.append("")

# ---- V-A regression block ----
try:
    va = pd.read_csv(os.path.join(RES_OUT, "VA1_regression_loocv.csv"))
    lines.append("## V-A regression — anchor-based, leave-one-out R²")
    lines.append("Targets are the 6 Russell anchors, so this measures how well each encoder separates emotion categories along V-A axes (NOT free continuous V-A).")
    lines.append("")
    lines.append("| Encoder | R² valence | R² arousal | R² overall | mean anchor err |")
    lines.append("|---|---|---|---|---|")
    for _, r in va.iterrows():
        lines.append(f"| `{r.encoder}` | {r.R2_valence:+.3f} | {r.R2_arousal:+.3f} | {r.R2_overall:+.3f} | {r.mean_err:.3f} |")
    lines.append("")
    top_va = va.iloc[0]
    verdict_va = ("real V-A signal" if top_va.R2_overall > 0.10 else "weak V-A signal — barely above category-mean prediction")
    lines.append(f"**Best V-A encoder: `{top_va.encoder}` (R² overall = {top_va.R2_overall:+.3f}) — {verdict_va}.**")
    lines.append("")
    lines.append("Pre vs post sampling on V-A R²:")
    for fam in ["audio_ib", "audio_mert", "text_ib", "text_clap"]:
        variants = [e for e in va.encoder.tolist() if e.startswith(fam)]
        if len(variants) < 2: continue
        deltas = []
        base = va[va.encoder == f"{fam}_orig"]
        if base.empty: base = va[va.encoder == fam]
        if base.empty: continue
        base_r2 = float(base.iloc[0].R2_overall)
        for v in variants:
            if v == base.iloc[0].encoder: continue
            r2v = float(va[va.encoder == v].iloc[0].R2_overall)
            deltas.append(f"{v}: {r2v:+.3f} (Δ {r2v - base_r2:+.3f})")
        if deltas:
            lines.append(f"- `{fam}` baseline R² = {base_r2:+.3f} →  " + " · ".join(deltas))
    lines.append("")
except Exception as _e:
    lines.append(f"<!-- V-A section skipped: {_e} -->")
    lines.append("")

# 5. Files index
# 5. Files index
lines.append("## Output files in this run")
for sub in ("embeddings", "results", "figures"):
    lines.append(f"### `{sub}/`")
    p = os.path.join(RUN_DIR, sub)
    for f in sorted(os.listdir(p)):
        lines.append(f"- `{f}`")
    lines.append("")

summary_path = os.path.join(RUN_DIR, "summary.md")
with open(summary_path, "w") as f:
    f.write("\n".join(lines))
print(f"\n💾 wrote {summary_path}")
print()
print("\n".join(lines[:30]))
print("\n…(truncated, see summary.md for full report)")
# Out:
# 💾 wrote /content/drive/MyDrive/DL_Project_2026/Explorations 2.0/run_2026-05-06_06-08/summary.md
#
# # Exploration run · 2026-05-06_06-08
#
# - N tracks: **150**
# - Encoder spaces analysed: **14**  (audio_ib_orig, audio_ib_random, audio_ib_energy, audio_mert_orig, audio_mert_random, audio_mert_energy, image_ib, image_clip, text_ib, text_ib_chorus, text_ib_multi, text_clap, text_clap_chorus, text_clap_multi)
# - Label schemes: **6**  (emotion, subcategory, contributor, genre_top, vocal, duration_bucket)
# - Re-extraction: **enabled**  (K=5 clips per track)
#
# ## What does each encoder actually organize by?
# Per encoder, we report the top label scheme by silhouette and by block contrast.  When both methods agree, that's a strong signal.
#
# | Encoder | Top label by silhouette | silhouette | Top label by block contrast | Δ |
# |---|---|---|---|---|
# | `audio_ib_orig` | contributor | -0.037 | genre_top | +0.085 |
# | `audio_ib_random` | contributor | -0.026 | genre_top | +0.081 |
# | `audio_ib_energy` | contributor | -0.033 | genre_top | +0.090 |
# | `audio_mert_orig` | contributor | -0.046 | genre_top | +0.011 |
# | `audio_mert_random` | contributor | -0.049 | genre_top | +0.011 |
# | `audio_mert_energy` | contributor | -0.046 | genre_top | +0.011 |
# | `image_ib` | contributor | -0.026 | genre_top | +0.023 |
# | `image_clip` | contributor | -0.025 | genre_top | +0.014 |
# | `text_ib` | contributor | -0.021 | genre_top | +0.023 |
# | `text_ib_chorus` | contributor | -0.032 | subcategory | +0.012 |
# | `text_ib_multi` | contributor | -0.024 | genre_top | +0.024 |
# | `text_clap` | contributor | -0.063 | subcategory | +0.013 |
# | `text_clap_chorus` | contributor | -0.041 | subcategory | +0.011 |
# | `text_clap_multi` | contributor | -0.066 | subcategory | +0.019 |
#
# ## Did the new audio + lyric sampling change anything?
# Compare the silhouette by emotion across the three audio_ib variants and three audio_mert variants:
#
#
# …(truncated, see summary.md for full report)

# %% [markdown]
# ## Next steps
#
# * **Inspect `summary.md`** — top-line answer to the "what does each encoder
#   group by" question lives there.
# * **Run the notebook a second time with a different `SEED`** in Cell 1 to
#   see how stable the random-K-mean audio embedding is across runs.
# * **Compare `audio_ib_orig` vs `audio_ib_random` vs `audio_ib_energy`** rows
#   in the silhouette / k-means / block-contrast tables — if energy-peak
#   sampling improves silhouette by emotion, the original mid-clip approach
#   was missing the genre-defining sections of the song.
# * **Open `results/method2_diagnostic_neighbors.txt`** to see, for the five
#   diagnostic tracks, exactly which neighbors each encoder pulls — the most
#   intuitive evidence of "what each encoder is really doing".
# * **Open `figures/method5_blocksort_*.png`** — if the `genre_top` panel has
#   a much cleaner block-diagonal than the `emotion` panel, that encoder is
#   organizing by genre, not by emotion.
